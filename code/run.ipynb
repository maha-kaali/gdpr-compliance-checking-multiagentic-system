# %%
from main import load_data, run_workflow, make_report

# %%
files = load_data()
# Out:
# Post-GDPR: 150 *.xml files found
# Pre-GDPR: 200 *.md files found

# %%
report = run_workflow([str(files[0])], local=False)
# Out:
# Gemini API model loaded
# Gemini API model loaded
# Gemini API model loaded
# Gemini API model loaded
# Gemini API model loaded

# %%
report
# Out:
# {'halted': False,
#  'inputs': {'document_paths': ['../data/post_gdpr/data/GoPPC-150/88.xml']},
#  'scope': {'applies': 'yes',
#   'reasons': ['The company states it is a "global company" and mentions "United States" as a storage location, indicating potential cross-border data transfers which fall under GDPR\'s purview if other conditions are met.',
#    "The policy describes collecting personal information like 'First and Last Name', 'Email Address', 'Username', 'Password', 'State and Country of Residence', and 'payment information', which are all 'personal data' as defined by GDPR.",
#    "The policy explicitly mentions that personal information 'may be transferred to and stored in the United States', suggesting data processing activities.",
#    "The policy is addressed to 'patrons, creators, and all users of our platform', implying a broad range of individuals whose data might be processed. If any of these individuals are in the Union, GDPR could apply.",
# ...

# %%
pdf_path = make_report(report)

# %%
# !pip install pypdf

# %%
pdf_path
# Out:
# PosixPath('/Users/jayasreemanoharan/Documents/IITB/CMInDS/Sem2/GenAgenticAI/PROJECT/code/reports/compliance_report_88_20260501_143909.pdf')
